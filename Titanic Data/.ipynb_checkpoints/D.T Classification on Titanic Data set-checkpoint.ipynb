# %%
import pandas as pd 
import numpy as np

# %%
train = pd.read_csv("./Train.csv")
train
# Out:
#       pclass  survived                                            name  \
# 0        3.0       0.0                         O'Donoghue, Ms. Bridget
# 1        2.0       0.0  Morley, Mr. Henry Samuel ("Mr Henry Marshall")
# 2        2.0       1.0                       Smith, Miss. Marion Elsie
# 3        3.0       1.0  Goldsmith, Mrs. Frank John (Emily Alice Brown)
# 4        3.0       1.0                              McCoy, Miss. Agnes
# ...      ...       ...                                             ...
# 1004     1.0       1.0                                Blank, Mr. Henry
# 1005     3.0       0.0                  Laitinen, Miss. Kristina Sofia
# 1006     1.0       1.0                          Newell, Miss. Marjorie
# 1007     3.0       1.0                    Nicola-Yarred, Master. Elias
# 1008     3.0       0.0                                 Corn, Mr. Harry
#
#          sex   age  sibsp  parch           ticket      fare cabin embarked  \
# 0     female   NaN    0.0    0.0           364856    7.7500   NaN        Q
# 1       male  39.0    0.0    0.0           250655   26.0000   NaN        S
# 2     female  40.0    0.0    0.0            31418   13.0000   NaN        S
# 3     female  31.0    1.0    1.0           363291   20.5250   NaN        S
# 4     female   NaN    2.0    0.0           367226   23.2500   NaN        Q
# ...      ...   ...    ...    ...              ...       ...   ...      ...
# 1004    male  40.0    0.0    0.0           112277   31.0000   A31        C
# 1005  female  37.0    0.0    0.0             4135    9.5875   NaN        S
# 1006  female  23.0    1.0    0.0            35273  113.2750   D36        C
# 1007    male  12.0    1.0    0.0             2651   11.2417   NaN        C
# 1008    male  30.0    0.0    0.0  SOTON/OQ 392090    8.0500   NaN        S
#
#      boat  body                          home.dest
# 0     NaN   NaN                                NaN
# 1     NaN   NaN                                NaN
# 2       9   NaN                                NaN
# 3     C D   NaN  Strood, Kent, England Detroit, MI
# 4      16   NaN                                NaN
# ...   ...   ...                                ...
# 1004    7   NaN                     Glen Ridge, NJ
# 1005  NaN   NaN                                NaN
# 1006    6   NaN                      Lexington, MA
# 1007    C   NaN                                NaN
# 1008  NaN   NaN                             London
#
# [1009 rows x 14 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1009 non-null   float64
#  1   survived   1009 non-null   float64
#  2   name       1009 non-null   object
#  3   sex        1009 non-null   object
#  4   age        812 non-null    float64
#  5   sibsp      1009 non-null   float64
#  6   parch      1009 non-null   float64
#  7   ticket     1009 non-null   object
#  8   fare       1008 non-null   float64
#  9   cabin      229 non-null    object
#  10  embarked   1008 non-null   object
#  11  boat       374 non-null    object
#  12  body       98 non-null     float64
#  13  home.dest  582 non-null    object
# dtypes: float64(7), object(7)
# memory usage: 110.5+ KB

# %%
# drop body, boat, cabin,home.dest
train.drop(labels=['body','boat','home.dest','cabin'], axis= 1, inplace= True)
# we will also drop 'names' , 'embarked' and 'ticket' as it wont help us in our classification 
train.drop(labels=['name', 'ticket', 'embarked'], axis= 1, inplace= True)
train
# Out:
#       pclass  survived     sex   age  sibsp  parch      fare
# 0        3.0       0.0  female   NaN    0.0    0.0    7.7500
# 1        2.0       0.0    male  39.0    0.0    0.0   26.0000
# 2        2.0       1.0  female  40.0    0.0    0.0   13.0000
# 3        3.0       1.0  female  31.0    1.0    1.0   20.5250
# 4        3.0       1.0  female   NaN    2.0    0.0   23.2500
# ...      ...       ...     ...   ...    ...    ...       ...
# 1004     1.0       1.0    male  40.0    0.0    0.0   31.0000
# 1005     3.0       0.0  female  37.0    0.0    0.0    9.5875
# 1006     1.0       1.0  female  23.0    1.0    0.0  113.2750
# 1007     3.0       1.0    male  12.0    1.0    0.0   11.2417
# 1008     3.0       0.0    male  30.0    0.0    0.0    8.0500
#
# [1009 rows x 7 columns]

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1009 non-null   float64
#  1   survived  1009 non-null   float64
#  2   sex       1009 non-null   object
#  3   age       812 non-null    float64
#  4   sibsp     1009 non-null   float64
#  5   parch     1009 non-null   float64
#  6   fare      1008 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 55.3+ KB

# %%
# as you see from info method above, age has (1009-812)-> 197 missing data! lets fill it by avaeage age 
train['age'] = train['age'].fillna(0)

# now take the average of ages 
m = np.mean( train['age'] ) 

# replace the 0 with the average 
train['age'] = train['age'].replace(0, m)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1009 non-null   float64
#  1   survived  1009 non-null   float64
#  2   sex       1009 non-null   object
#  3   age       1009 non-null   float64
#  4   sibsp     1009 non-null   float64
#  5   parch     1009 non-null   float64
#  6   fare      1008 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 55.3+ KB

# %%
# we still have one missing data in 'fare' and 'embark'
train['fare'] = train['fare'].fillna(np.mean( train['fare']))

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009 entries, 0 to 1008
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    1009 non-null   float64
#  1   survived  1009 non-null   float64
#  2   sex       1009 non-null   object
#  3   age       1009 non-null   float64
#  4   sibsp     1009 non-null   float64
#  5   parch     1009 non-null   float64
#  6   fare      1009 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 55.3+ KB

# %%
# Now we do not have any missing data

# %%
# lets label encode our "sex" column and "embarked"
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['sex'] = le.fit_transform(train['sex'])

# %%
# except "Survived Column" i need all other as X
X = train.loc[:, train.columns != 'survived']
X
# Out:
#       pclass  sex        age  sibsp  parch      fare
# 0        3.0    0  24.013132    0.0    0.0    7.7500
# 1        2.0    1  39.000000    0.0    0.0   26.0000
# 2        2.0    0  40.000000    0.0    0.0   13.0000
# 3        3.0    0  31.000000    1.0    1.0   20.5250
# 4        3.0    0  24.013132    2.0    0.0   23.2500
# ...      ...  ...        ...    ...    ...       ...
# 1004     1.0    1  40.000000    0.0    0.0   31.0000
# 1005     3.0    0  37.000000    0.0    0.0    9.5875
# 1006     1.0    0  23.000000    1.0    0.0  113.2750
# 1007     3.0    1  12.000000    1.0    0.0   11.2417
# 1008     3.0    1  30.000000    0.0    0.0    8.0500
#
# [1009 rows x 6 columns]

# %%
X = X.values

# %%
y = train.loc[:,  train.columns == 'survived']
y
# Out:
#       survived
# 0          0.0
# 1          0.0
# 2          1.0
# 3          1.0
# 4          1.0
# ...        ...
# 1004       1.0
# 1005       0.0
# 1006       1.0
# 1007       1.0
# 1008       0.0
#
# [1009 rows x 1 columns]

# %%
y = y.values.astype('int')
y
# Out:
# array([[0],
#        [0],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]])

# %% [markdown]
# ## to split our data for training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
...     X, y, test_size=0.1, random_state=2)

# %% [markdown]
# ### To create and train our model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(criterion='entropy')

# %%
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = dt.predict(X_test)

# %% [markdown]
# ### To valideate our mode

# %%
from sklearn.metrics import accuracy_score
print(f'the accuracy of the model is , {accuracy_score(y_test, y_pred)*100} percent ' )
# Out:
# the accuracy of the model is , 78.21782178217822 percent

# %% [markdown]
# ### to plot our decission tree

# %%
from sklearn.tree import plot_tree


## here if i directly plot my tree will be very small to increase the tree size 

from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 80,80

# %%
plot_tree(dt)
# Out:
# [Text(1669.8778698979593, 4258.2, 'X[1] <= 0.5\nentropy = 0.957\nsamples = 908\nvalue = [564, 344]'),
#  Text(906.9872448979593, 4077.0, 'X[0] <= 2.5\nentropy = 0.878\nsamples = 326\nvalue = [97, 229]'),
#  Text(459.30612244897964, 3895.8, 'X[5] <= 31.681\nentropy = 0.386\nsamples = 172\nvalue = [13, 159]'),
#  Text(326.44897959183675, 3714.6000000000004, 'X[2] <= 21.5\nentropy = 0.631\nsamples = 63\nvalue = [10, 53]'),
#  Text(296.08163265306126, 3533.4, 'entropy = 0.0\nsamples = 10\nvalue = [0, 10]'),
#  Text(356.8163265306123, 3533.4, 'X[5] <= 31.34\nentropy = 0.699\nsamples = 53\nvalue = [10, 43]'),
#  Text(326.44897959183675, 3352.2, 'X[2] <= 27.5\nentropy = 0.665\nsamples = 52\nvalue = [9, 43]'),
#  Text(182.20408163265307, 3171.0, 'X[5] <= 26.86\nentropy = 0.918\nsamples = 15\nvalue = [5, 10]'),
#  Text(151.83673469387756, 2989.8, 'X[5] <= 17.429\nentropy = 0.98\nsamples = 12\nvalue = [5, 7]'),
#  Text(91.10204081632654, 2808.6000000000004, 'X[2] <= 25.0\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(60.734693877551024, 2627.4, 'X[2] <= 23.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(30.367346938775512, 2446.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(91.10204081632654, 2446.2, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(121.46938775510205, 2627.4, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(212.57142857142858, 2808.6000000000004, 'X[5] <= 23.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(182.20408163265307, 2627.4, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(242.9387755102041, 2627.4, 'X[2] <= 25.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(212.57142857142858, 2446.2, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(273.30612244897964, 2446.2, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(212.57142857142858, 2989.8, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(470.6938775510204, 3171.0, 'X[5] <= 28.217\nentropy = 0.494\nsamples = 37\nvalue = [4, 33]'),
#  Text(394.7755102040817, 2989.8, 'X[5] <= 11.425\nentropy = 0.422\nsamples = 35\nvalue = [3, 32]'),
#  Text(334.0408163265306, 2808.6000000000004, 'X[2] <= 53.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(303.6734693877551, 2627.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(364.40816326530614, 2627.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(455.51020408163265, 2808.6000000000004, 'X[2] <= 30.5\nentropy = 0.337\nsamples = 32\nvalue = [2, 30]'),
#  Text(425.14285714285717, 2627.4, 'X[2] <= 28.5\nentropy = 0.65\nsamples = 12\nvalue = [2, 10]'),
#  Text(394.7755102040817, 2446.2, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(455.51020408163265, 2446.2, 'X[3] <= 2.0\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(425.14285714285717, 2265.0, 'X[5] <= 12.675\nentropy = 0.811\nsamples = 8\nvalue = [2, 6]'),
#  Text(394.7755102040817, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(455.51020408163265, 2083.8, 'X[5] <= 13.429\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(425.14285714285717, 1902.6, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(485.8775510204082, 1902.6, 'X[5] <= 19.929\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(455.51020408163265, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(516.2448979591837, 1721.4, 'entropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(485.8775510204082, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(485.8775510204082, 2627.4, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]'),
#  Text(546.6122448979593, 2989.8, 'X[2] <= 40.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(516.2448979591837, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(576.9795918367347, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(387.18367346938777, 3352.2, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(592.1632653061225, 3714.6000000000004, 'X[5] <= 149.035\nentropy = 0.182\nsamples = 109\nvalue = [3, 106]'),
#  Text(561.795918367347, 3533.4, 'entropy = 0.0\nsamples = 84\nvalue = [0, 84]'),
#  Text(622.530612244898, 3533.4, 'X[5] <= 152.506\nentropy = 0.529\nsamples = 25\nvalue = [3, 22]'),
#  Text(561.795918367347, 3352.2, 'X[2] <= 29.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(531.4285714285714, 3171.0, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(592.1632653061225, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(683.265306122449, 3352.2, 'X[2] <= 61.5\nentropy = 0.267\nsamples = 22\nvalue = [1, 21]'),
#  Text(652.8979591836735, 3171.0, 'entropy = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(713.6326530612246, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1354.6683673469388, 3895.8, 'X[5] <= 24.808\nentropy = 0.994\nsamples = 154\nvalue = [84, 70]'),
#  Text(1130.234693877551, 3714.6000000000004, 'X[5] <= 7.256\nentropy = 0.999\nsamples = 134\nvalue = [65, 69]'),
#  Text(990.7346938775511, 3533.4, 'X[5] <= 6.85\nentropy = 0.503\nsamples = 9\nvalue = [1, 8]'),
#  Text(960.3673469387755, 3352.2, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1021.1020408163266, 3352.2, 'entropy = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1269.734693877551, 3533.4, 'X[2] <= 27.5\nentropy = 1.0\nsamples = 125\nvalue = [64, 61]'),
#  Text(1081.8367346938776, 3352.2, 'X[5] <= 14.873\nentropy = 0.994\nsamples = 99\nvalue = [45, 54]'),
#  Text(857.8775510204082, 3171.0, 'X[5] <= 8.081\nentropy = 0.999\nsamples = 71\nvalue = [37, 34]'),
#  Text(668.0816326530612, 2989.8, 'X[2] <= 26.5\nentropy = 0.968\nsamples = 43\nvalue = [17, 26]'),
#  Text(637.7142857142858, 2808.6000000000004, 'X[2] <= 15.0\nentropy = 0.947\nsamples = 41\nvalue = [15, 26]'),
#  Text(607.3469387755102, 2627.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(668.0816326530612, 2627.4, 'X[2] <= 16.5\nentropy = 0.934\nsamples = 40\nvalue = [14, 26]'),
#  Text(637.7142857142858, 2446.2, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(698.4489795918367, 2446.2, 'X[5] <= 7.39\nentropy = 0.957\nsamples = 37\nvalue = [14, 23]'),
#  Text(668.0816326530612, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(728.8163265306123, 2265.0, 'X[5] <= 7.59\nentropy = 0.944\nsamples = 36\nvalue = [13, 23]'),
#  Text(698.4489795918367, 2083.8, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(759.1836734693878, 2083.8, 'X[5] <= 7.64\nentropy = 0.96\nsamples = 34\nvalue = [13, 21]'),
#  Text(728.8163265306123, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(789.5510204081634, 1902.6, 'X[5] <= 7.727\nentropy = 0.946\nsamples = 33\nvalue = [12, 21]'),
#  Text(759.1836734693878, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(819.9183673469388, 1721.4, 'X[5] <= 7.742\nentropy = 0.963\nsamples = 31\nvalue = [12, 19]'),
#  Text(789.5510204081634, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(850.2857142857143, 1540.1999999999998, 'X[2] <= 22.5\nentropy = 0.948\nsamples = 30\nvalue = [11, 19]'),
#  Text(789.5510204081634, 1359.0, 'X[2] <= 18.5\nentropy = 0.764\nsamples = 9\nvalue = [2, 7]'),
#  Text(759.1836734693878, 1177.7999999999997, 'X[5] <= 7.902\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(728.8163265306123, 996.5999999999999, 'X[5] <= 7.827\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(698.4489795918367, 815.3999999999996, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(759.1836734693878, 815.3999999999996, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(789.5510204081634, 996.5999999999999, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(819.9183673469388, 1177.7999999999997, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(911.0204081632653, 1359.0, 'X[4] <= 1.0\nentropy = 0.985\nsamples = 21\nvalue = [9, 12]'),
#  Text(880.6530612244899, 1177.7999999999997, 'X[3] <= 0.5\nentropy = 0.971\nsamples = 20\nvalue = [8, 12]'),
#  Text(850.2857142857143, 996.5999999999999, 'X[2] <= 25.007\nentropy = 0.949\nsamples = 19\nvalue = [7, 12]'),
#  Text(819.9183673469388, 815.3999999999996, 'X[5] <= 7.902\nentropy = 0.964\nsamples = 18\nvalue = [7, 11]'),
#  Text(759.1836734693878, 634.1999999999998, 'X[5] <= 7.79\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(728.8163265306123, 453.0, 'X[2] <= 24.007\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(698.4489795918367, 271.7999999999997, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(759.1836734693878, 271.7999999999997, 'entropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(789.5510204081634, 453.0, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(880.6530612244899, 634.1999999999998, 'X[5] <= 7.988\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(850.2857142857143, 453.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(911.0204081632653, 453.0, 'X[2] <= 23.507\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(880.6530612244899, 271.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(941.3877551020408, 271.7999999999997, 'entropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(880.6530612244899, 815.3999999999996, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(911.0204081632653, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(941.3877551020408, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(698.4489795918367, 2808.6000000000004, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1047.6734693877552, 2989.8, 'X[5] <= 8.906\nentropy = 0.863\nsamples = 28\nvalue = [20, 8]'),
#  Text(1017.3061224489796, 2808.6000000000004, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(1078.0408163265306, 2808.6000000000004, 'X[2] <= 26.5\nentropy = 0.959\nsamples = 21\nvalue = [13, 8]'),
#  Text(1047.6734693877552, 2627.4, 'X[2] <= 19.0\nentropy = 0.9\nsamples = 19\nvalue = [13, 6]'),
#  Text(971.7551020408164, 2446.2, 'X[4] <= 0.5\nentropy = 1.0\nsamples = 10\nvalue = [5, 5]'),
#  Text(911.0204081632653, 2265.0, 'X[5] <= 13.465\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(880.6530612244899, 2083.8, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(941.3877551020408, 2083.8, 'X[5] <= 14.456\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(911.0204081632653, 1902.6, 'X[2] <= 14.75\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(880.6530612244899, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(941.3877551020408, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(971.7551020408164, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1032.4897959183675, 2265.0, 'X[5] <= 12.235\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1002.1224489795919, 2083.8, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1062.857142857143, 2083.8, 'X[5] <= 13.371\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1032.4897959183675, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1093.2244897959185, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1123.591836734694, 2446.2, 'X[5] <= 9.394\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(1093.2244897959185, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1153.9591836734694, 2265.0, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(1108.4081632653063, 2627.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1305.795918367347, 3171.0, 'X[3] <= 2.5\nentropy = 0.863\nsamples = 28\nvalue = [8, 20]'),
#  Text(1275.4285714285716, 2989.8, 'X[3] <= 0.5\nentropy = 0.779\nsamples = 26\nvalue = [6, 20]'),
#  Text(1245.061224489796, 2808.6000000000004, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(1305.795918367347, 2808.6000000000004, 'X[4] <= 1.5\nentropy = 0.863\nsamples = 21\nvalue = [6, 15]'),
#  Text(1275.4285714285716, 2627.4, 'X[5] <= 21.119\nentropy = 0.811\nsamples = 20\nvalue = [5, 15]'),
#  Text(1245.061224489796, 2446.2, 'X[2] <= 1.5\nentropy = 0.896\nsamples = 16\nvalue = [5, 11]'),
#  Text(1214.6938775510205, 2265.0, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1275.4285714285716, 2265.0, 'X[2] <= 3.0\nentropy = 0.961\nsamples = 13\nvalue = [5, 8]'),
#  Text(1245.061224489796, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1305.795918367347, 2083.8, 'X[2] <= 25.007\nentropy = 0.918\nsamples = 12\nvalue = [4, 8]'),
#  Text(1275.4285714285716, 1902.6, 'X[2] <= 21.5\nentropy = 0.845\nsamples = 11\nvalue = [3, 8]'),
#  Text(1245.061224489796, 1721.4, 'X[4] <= 0.5\nentropy = 0.985\nsamples = 7\nvalue = [3, 4]'),
#  Text(1214.6938775510205, 1540.1999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1275.4285714285716, 1540.1999999999998, 'X[5] <= 15.494\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(1245.061224489796, 1359.0, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1305.795918367347, 1359.0, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1305.795918367347, 1721.4, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1336.1632653061224, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1305.795918367347, 2446.2, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(1336.1632653061224, 2627.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1336.1632653061224, 2989.8, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1457.6326530612246, 3352.2, 'X[5] <= 8.673\nentropy = 0.84\nsamples = 26\nvalue = [19, 7]'),
#  Text(1427.2653061224491, 3171.0, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(1488.0, 3171.0, 'X[5] <= 20.825\nentropy = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(1457.6326530612246, 2989.8, 'X[5] <= 19.125\nentropy = 0.989\nsamples = 16\nvalue = [9, 7]'),
#  Text(1427.2653061224491, 2808.6000000000004, 'X[5] <= 9.079\nentropy = 0.89\nsamples = 13\nvalue = [9, 4]'),
#  Text(1396.8979591836735, 2627.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1457.6326530612246, 2627.4, 'X[2] <= 54.0\nentropy = 0.811\nsamples = 12\nvalue = [9, 3]'),
#  Text(1427.2653061224491, 2446.2, 'X[5] <= 14.85\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(1396.8979591836735, 2265.0, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(1457.6326530612246, 2265.0, 'X[4] <= 1.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(1427.2653061224491, 2083.8, 'X[2] <= 34.0\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1396.8979591836735, 1902.6, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1457.6326530612246, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1488.0, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1488.0, 2446.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1488.0, 2808.6000000000004, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1518.3673469387757, 2989.8, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1579.1020408163267, 3714.6000000000004, 'X[4] <= 4.5\nentropy = 0.286\nsamples = 20\nvalue = [19, 1]'),
#  Text(1548.734693877551, 3533.4, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(1609.4693877551022, 3533.4, 'X[4] <= 5.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1579.1020408163267, 3352.2, 'X[2] <= 38.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1548.734693877551, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1609.4693877551022, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1639.8367346938776, 3352.2, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2432.7684948979595, 4077.0, 'X[2] <= 14.25\nentropy = 0.717\nsamples = 582\nvalue = [467, 115]'),
#  Text(1822.0408163265306, 3895.8, 'X[3] <= 2.5\nentropy = 0.979\nsamples = 41\nvalue = [17, 24]'),
#  Text(1761.3061224489797, 3714.6000000000004, 'X[5] <= 15.573\nentropy = 0.402\nsamples = 25\nvalue = [2, 23]'),
#  Text(1730.938775510204, 3533.4, 'X[5] <= 13.488\nentropy = 0.684\nsamples = 11\nvalue = [2, 9]'),
#  Text(1700.5714285714287, 3352.2, 'entropy = 0.0\nsamples = 7\nvalue = [0, 7]'),
#  Text(1761.3061224489797, 3352.2, 'X[0] <= 2.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(1730.938775510204, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1791.6734693877552, 3171.0, 'X[5] <= 14.873\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(1761.3061224489797, 2989.8, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1822.0408163265306, 2989.8, 'X[2] <= 6.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1791.6734693877552, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1852.4081632653063, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1791.6734693877552, 3533.4, 'entropy = 0.0\nsamples = 14\nvalue = [0, 14]'),
#  Text(1882.7755102040817, 3714.6000000000004, 'X[2] <= 3.5\nentropy = 0.337\nsamples = 16\nvalue = [15, 1]'),
#  Text(1852.4081632653063, 3533.4, 'X[2] <= 2.5\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(1822.0408163265306, 3352.2, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(1882.7755102040817, 3352.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1913.1428571428573, 3533.4, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(3043.496173469388, 3895.8, 'X[0] <= 1.5\nentropy = 0.654\nsamples = 541\nvalue = [450, 91]'),
#  Text(2171.265306122449, 3714.6000000000004, 'X[5] <= 89.552\nentropy = 0.912\nsamples = 110\nvalue = [74, 36]'),
#  Text(2064.979591836735, 3533.4, 'X[2] <= 60.5\nentropy = 0.956\nsamples = 90\nvalue = [56, 34]'),
#  Text(2004.2448979591838, 3352.2, 'X[2] <= 22.0\nentropy = 0.975\nsamples = 81\nvalue = [48, 33]'),
#  Text(1973.8775510204082, 3171.0, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2034.6122448979593, 3171.0, 'X[2] <= 23.5\nentropy = 0.983\nsamples = 78\nvalue = [45, 33]'),
#  Text(2004.2448979591838, 2989.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2064.979591836735, 2989.8, 'X[5] <= 37.0\nentropy = 0.979\nsamples = 77\nvalue = [45, 32]'),
#  Text(1913.1428571428573, 2808.6000000000004, 'X[2] <= 57.0\nentropy = 0.999\nsamples = 46\nvalue = [24, 22]'),
#  Text(1882.7755102040817, 2627.4, 'X[5] <= 25.665\nentropy = 1.0\nsamples = 44\nvalue = [22, 22]'),
#  Text(1822.0408163265306, 2446.2, 'X[2] <= 48.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(1791.6734693877552, 2265.0, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(1852.4081632653063, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1943.5102040816328, 2446.2, 'X[4] <= 0.5\nentropy = 0.996\nsamples = 39\nvalue = [18, 21]'),
#  Text(1913.1428571428573, 2265.0, 'X[5] <= 25.871\nentropy = 0.992\nsamples = 38\nvalue = [17, 21]'),
#  Text(1882.7755102040817, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1943.5102040816328, 2083.8, 'X[5] <= 26.144\nentropy = 0.995\nsamples = 37\nvalue = [17, 20]'),
#  Text(1882.7755102040817, 1902.6, 'X[2] <= 24.507\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1852.4081632653063, 1721.4, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1913.1428571428573, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2004.2448979591838, 1902.6, 'X[5] <= 26.419\nentropy = 0.983\nsamples = 33\nvalue = [14, 19]'),
#  Text(1973.8775510204082, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2034.6122448979593, 1721.4, 'X[3] <= 0.5\nentropy = 0.993\nsamples = 31\nvalue = [14, 17]'),
#  Text(2004.2448979591838, 1540.1999999999998, 'X[5] <= 29.1\nentropy = 0.997\nsamples = 30\nvalue = [14, 16]'),
#  Text(1897.9591836734694, 1359.0, 'X[2] <= 26.007\nentropy = 0.989\nsamples = 16\nvalue = [9, 7]'),
#  Text(1837.2244897959185, 1177.7999999999997, 'X[5] <= 27.135\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(1806.857142857143, 996.5999999999999, 'entropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1867.591836734694, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1958.6938775510205, 1177.7999999999997, 'X[2] <= 54.5\nentropy = 0.994\nsamples = 11\nvalue = [5, 6]'),
#  Text(1928.326530612245, 996.5999999999999, 'X[2] <= 46.75\nentropy = 0.971\nsamples = 10\nvalue = [4, 6]'),
#  Text(1897.9591836734694, 815.3999999999996, 'X[5] <= 27.15\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(1867.591836734694, 634.1999999999998, 'X[2] <= 38.5\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(1837.2244897959185, 453.0, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1897.9591836734694, 453.0, 'X[2] <= 43.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(1867.591836734694, 271.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1928.326530612245, 271.7999999999997, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1928.326530612245, 634.1999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1958.6938775510205, 815.3999999999996, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(1989.0612244897961, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2110.5306122448983, 1359.0, 'X[2] <= 28.0\nentropy = 0.94\nsamples = 14\nvalue = [5, 9]'),
#  Text(2080.1632653061224, 1177.7999999999997, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(2140.8979591836737, 1177.7999999999997, 'X[2] <= 51.5\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(2110.5306122448983, 996.5999999999999, 'X[5] <= 32.51\nentropy = 0.954\nsamples = 8\nvalue = [5, 3]'),
#  Text(2080.1632653061224, 815.3999999999996, 'X[5] <= 30.75\nentropy = 1.0\nsamples = 6\nvalue = [3, 3]'),
#  Text(2049.795918367347, 634.1999999999998, 'X[2] <= 43.0\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(2019.4285714285716, 453.0, 'X[2] <= 35.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(1989.0612244897961, 271.7999999999997, 'X[2] <= 30.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(1958.6938775510205, 90.59999999999945, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2019.4285714285716, 90.59999999999945, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2049.795918367347, 271.7999999999997, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2080.1632653061224, 453.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2110.5306122448983, 634.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2140.8979591836737, 815.3999999999996, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2171.265306122449, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2064.979591836735, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(1973.8775510204082, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1943.5102040816328, 2627.4, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2216.8163265306125, 2808.6000000000004, 'X[5] <= 52.277\nentropy = 0.907\nsamples = 31\nvalue = [21, 10]'),
#  Text(2186.448979591837, 2627.4, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(2247.183673469388, 2627.4, 'X[2] <= 52.5\nentropy = 0.998\nsamples = 21\nvalue = [11, 10]'),
#  Text(2216.8163265306125, 2446.2, 'X[5] <= 58.875\nentropy = 0.964\nsamples = 18\nvalue = [11, 7]'),
#  Text(2125.714285714286, 2265.0, 'X[2] <= 49.5\nentropy = 0.863\nsamples = 7\nvalue = [2, 5]'),
#  Text(2095.3469387755104, 2083.8, 'X[2] <= 33.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5]'),
#  Text(2064.979591836735, 1902.6, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2125.714285714286, 1902.6, 'X[5] <= 52.827\nentropy = 0.811\nsamples = 4\nvalue = [1, 3]'),
#  Text(2095.3469387755104, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2156.081632653061, 1721.4, 'X[2] <= 43.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2125.714285714286, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2186.448979591837, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2156.081632653061, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2307.918367346939, 2265.0, 'X[5] <= 85.638\nentropy = 0.684\nsamples = 11\nvalue = [9, 2]'),
#  Text(2277.5510204081634, 2083.8, 'X[2] <= 27.5\nentropy = 0.469\nsamples = 10\nvalue = [9, 1]'),
#  Text(2247.183673469388, 1902.6, 'X[2] <= 25.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2216.8163265306125, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2277.5510204081634, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2307.918367346939, 1902.6, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(2338.285714285714, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2277.5510204081634, 2446.2, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(2125.714285714286, 3352.2, 'X[2] <= 75.5\nentropy = 0.503\nsamples = 9\nvalue = [8, 1]'),
#  Text(2095.3469387755104, 3171.0, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(2156.081632653061, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2277.5510204081634, 3533.4, 'X[5] <= 387.665\nentropy = 0.469\nsamples = 20\nvalue = [18, 2]'),
#  Text(2247.183673469388, 3352.2, 'X[3] <= 1.5\nentropy = 0.297\nsamples = 19\nvalue = [18, 1]'),
#  Text(2216.8163265306125, 3171.0, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(2277.5510204081634, 3171.0, 'X[2] <= 47.0\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2247.183673469388, 2989.8, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2307.918367346939, 2989.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2307.918367346939, 3352.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3915.7270408163267, 3714.6000000000004, 'X[2] <= 32.25\nentropy = 0.551\nsamples = 431\nvalue = [376, 55]'),
#  Text(3519.2908163265306, 3533.4, 'X[2] <= 24.75\nentropy = 0.611\nsamples = 332\nvalue = [282, 50]'),
#  Text(3081.3367346938776, 3352.2, 'X[2] <= 17.5\nentropy = 0.52\nsamples = 231\nvalue = [204, 27]'),
#  Text(3050.969387755102, 3171.0, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(3111.704081632653, 3171.0, 'X[3] <= 1.5\nentropy = 0.545\nsamples = 215\nvalue = [188, 27]'),
#  Text(3081.3367346938776, 2989.8, 'X[4] <= 0.5\nentropy = 0.566\nsamples = 203\nvalue = [176, 27]'),
#  Text(2871.6122448979595, 2808.6000000000004, 'X[5] <= 7.025\nentropy = 0.525\nsamples = 194\nvalue = [171, 23]'),
#  Text(2841.2448979591836, 2627.4, 'entropy = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(2901.979591836735, 2627.4, 'X[5] <= 7.825\nentropy = 0.545\nsamples = 183\nvalue = [160, 23]'),
#  Text(2634.367346938776, 2446.2, 'X[5] <= 7.763\nentropy = 0.684\nsamples = 66\nvalue = [54, 12]'),
#  Text(2474.9387755102043, 2265.0, 'X[5] <= 7.183\nentropy = 0.55\nsamples = 55\nvalue = [48, 7]'),
#  Text(2399.0204081632655, 2083.8, 'X[5] <= 7.133\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(2368.65306122449, 1902.6, 'X[2] <= 24.007\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(2338.285714285714, 1721.4, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2399.0204081632655, 1721.4, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2429.387755102041, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2550.857142857143, 2083.8, 'X[5] <= 7.742\nentropy = 0.475\nsamples = 49\nvalue = [44, 5]'),
#  Text(2490.122448979592, 1902.6, 'X[5] <= 7.24\nentropy = 0.353\nsamples = 30\nvalue = [28, 2]'),
#  Text(2459.7551020408164, 1721.4, 'X[2] <= 20.5\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]'),
#  Text(2399.0204081632655, 1540.1999999999998, 'X[2] <= 19.25\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2368.65306122449, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2429.387755102041, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2520.4897959183677, 1540.1999999999998, 'X[5] <= 7.227\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(2490.122448979592, 1359.0, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(2550.857142857143, 1359.0, 'X[2] <= 23.757\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(2520.4897959183677, 1177.7999999999997, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2581.2244897959185, 1177.7999999999997, 'entropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(2520.4897959183677, 1721.4, 'entropy = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(2611.591836734694, 1902.6, 'X[2] <= 21.007\nentropy = 0.629\nsamples = 19\nvalue = [16, 3]'),
#  Text(2581.2244897959185, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2641.9591836734694, 1721.4, 'X[3] <= 0.5\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(2611.591836734694, 1540.1999999999998, 'entropy = 0.696\nsamples = 16\nvalue = [13, 3]'),
#  Text(2672.326530612245, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2793.795918367347, 2265.0, 'X[5] <= 7.81\nentropy = 0.994\nsamples = 11\nvalue = [6, 5]'),
#  Text(2763.4285714285716, 2083.8, 'X[5] <= 7.798\nentropy = 0.971\nsamples = 10\nvalue = [6, 4]'),
#  Text(2733.061224489796, 1902.6, 'X[2] <= 19.5\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(2702.6938775510207, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2763.4285714285716, 1721.4, 'X[2] <= 21.5\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(2733.061224489796, 1540.1999999999998, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2793.795918367347, 1540.1999999999998, 'X[2] <= 22.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(2763.4285714285716, 1359.0, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(2824.1632653061224, 1359.0, 'X[2] <= 23.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(2793.795918367347, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(2854.5306122448983, 1177.7999999999997, 'X[2] <= 24.007\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(2824.1632653061224, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2884.8979591836737, 996.5999999999999, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2793.795918367347, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(2824.1632653061224, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3169.591836734694, 2446.2, 'X[2] <= 20.5\nentropy = 0.45\nsamples = 117\nvalue = [106, 11]'),
#  Text(2945.6326530612246, 2265.0, 'X[5] <= 8.175\nentropy = 0.722\nsamples = 25\nvalue = [20, 5]'),
#  Text(2884.8979591836737, 2083.8, 'X[5] <= 7.91\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(2854.5306122448983, 1902.6, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(2915.265306122449, 1902.6, 'X[2] <= 19.5\nentropy = 0.722\nsamples = 5\nvalue = [1, 4]'),
#  Text(2884.8979591836737, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(2945.6326530612246, 1721.4, 'X[3] <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(2915.265306122449, 1540.1999999999998, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(2976.0, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3006.367346938776, 2083.8, 'X[2] <= 19.5\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]'),
#  Text(2976.0, 1902.6, 'entropy = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(3036.7346938775513, 1902.6, 'X[5] <= 11.854\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3006.367346938776, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3067.1020408163267, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3393.5510204081634, 2265.0, 'X[5] <= 40.323\nentropy = 0.348\nsamples = 92\nvalue = [86, 6]'),
#  Text(3294.857142857143, 2083.8, 'X[0] <= 2.5\nentropy = 0.267\nsamples = 88\nvalue = [84, 4]'),
#  Text(3188.571428571429, 1902.6, 'X[5] <= 11.0\nentropy = 0.672\nsamples = 17\nvalue = [14, 3]'),
#  Text(3127.8367346938776, 1721.4, 'X[2] <= 22.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(3097.469387755102, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3158.2040816326535, 1540.1999999999998, 'X[2] <= 23.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3127.8367346938776, 1359.0, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3188.571428571429, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3249.3061224489797, 1721.4, 'X[5] <= 13.681\nentropy = 0.414\nsamples = 12\nvalue = [11, 1]'),
#  Text(3218.9387755102043, 1540.1999999999998, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(3279.673469387755, 1540.1999999999998, 'X[5] <= 14.454\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3249.3061224489797, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3310.0408163265306, 1359.0, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3401.1428571428573, 1902.6, 'X[5] <= 7.892\nentropy = 0.107\nsamples = 71\nvalue = [70, 1]'),
#  Text(3370.775510204082, 1721.4, 'X[5] <= 7.883\nentropy = 0.544\nsamples = 8\nvalue = [7, 1]'),
#  Text(3340.4081632653065, 1540.1999999999998, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(3401.1428571428573, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3431.5102040816328, 1721.4, 'entropy = 0.0\nsamples = 63\nvalue = [63, 0]'),
#  Text(3492.244897959184, 2083.8, 'X[0] <= 2.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(3461.877551020408, 1902.6, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3522.6122448979595, 1902.6, 'entropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(3291.061224489796, 2808.6000000000004, 'X[5] <= 22.904\nentropy = 0.991\nsamples = 9\nvalue = [5, 4]'),
#  Text(3260.6938775510207, 2627.4, 'X[5] <= 14.873\nentropy = 0.918\nsamples = 6\nvalue = [2, 4]'),
#  Text(3230.3265306122453, 2446.2, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3291.061224489796, 2446.2, 'entropy = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(3321.4285714285716, 2627.4, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3142.071428571429, 2989.8, 'entropy = 0.0\nsamples = 12\nvalue = [12, 0]'),
#  Text(3957.244897959184, 3352.2, 'X[5] <= 7.01\nentropy = 0.774\nsamples = 101\nvalue = [78, 23]'),
#  Text(3926.877551020408, 3171.0, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3987.6122448979595, 3171.0, 'X[5] <= 49.038\nentropy = 0.746\nsamples = 99\nvalue = [78, 21]'),
#  Text(3860.448979591837, 2989.8, 'X[5] <= 10.0\nentropy = 0.718\nsamples = 96\nvalue = [77, 19]'),
#  Text(3697.2244897959185, 2808.6000000000004, 'X[5] <= 7.227\nentropy = 0.827\nsamples = 50\nvalue = [37, 13]'),
#  Text(3666.857142857143, 2627.4, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(3727.591836734694, 2627.4, 'X[2] <= 25.5\nentropy = 0.867\nsamples = 45\nvalue = [32, 13]'),
#  Text(3613.714285714286, 2446.2, 'X[5] <= 7.44\nentropy = 0.991\nsamples = 9\nvalue = [4, 5]'),
#  Text(3583.3469387755104, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3644.081632653061, 2265.0, 'X[5] <= 8.698\nentropy = 1.0\nsamples = 8\nvalue = [4, 4]'),
#  Text(3613.714285714286, 2083.8, 'X[5] <= 7.846\nentropy = 0.985\nsamples = 7\nvalue = [4, 3]'),
#  Text(3583.3469387755104, 1902.6, 'X[5] <= 7.758\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(3552.979591836735, 1721.4, 'X[5] <= 7.696\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3522.6122448979595, 1540.1999999999998, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3583.3469387755104, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3613.714285714286, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(3644.081632653061, 1902.6, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3674.448979591837, 2083.8, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3841.469387755102, 2446.2, 'X[2] <= 28.75\nentropy = 0.764\nsamples = 36\nvalue = [28, 8]'),
#  Text(3765.5510204081634, 2265.0, 'X[2] <= 26.5\nentropy = 0.323\nsamples = 17\nvalue = [16, 1]'),
#  Text(3735.183673469388, 2083.8, 'X[5] <= 7.815\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3704.8163265306125, 1902.6, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3765.5510204081634, 1902.6, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(3795.918367346939, 2083.8, 'entropy = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(3917.387755102041, 2265.0, 'X[5] <= 9.492\nentropy = 0.949\nsamples = 19\nvalue = [12, 7]'),
#  Text(3887.0204081632655, 2083.8, 'X[2] <= 31.5\nentropy = 0.874\nsamples = 17\nvalue = [12, 5]'),
#  Text(3826.2857142857147, 1902.6, 'X[5] <= 7.988\nentropy = 0.75\nsamples = 14\nvalue = [11, 3]'),
#  Text(3795.918367346939, 1721.4, 'X[5] <= 7.885\nentropy = 0.845\nsamples = 11\nvalue = [8, 3]'),
#  Text(3735.183673469388, 1540.1999999999998, 'X[2] <= 29.5\nentropy = 0.592\nsamples = 7\nvalue = [6, 1]'),
#  Text(3704.8163265306125, 1359.0, 'X[5] <= 7.763\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(3674.448979591837, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3735.183673469388, 1177.7999999999997, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3765.5510204081634, 1359.0, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3856.65306122449, 1540.1999999999998, 'X[2] <= 30.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 2]'),
#  Text(3826.2857142857147, 1359.0, 'X[5] <= 7.91\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(3795.918367346939, 1177.7999999999997, 'X[2] <= 29.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3765.5510204081634, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3826.2857142857147, 996.5999999999999, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3856.65306122449, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(3887.0204081632655, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3856.65306122449, 1721.4, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(3947.7551020408164, 1902.6, 'X[5] <= 7.815\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(3917.387755102041, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(3978.1224489795923, 1721.4, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(3947.7551020408164, 2083.8, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4023.673469387755, 2808.6000000000004, 'X[5] <= 11.619\nentropy = 0.559\nsamples = 46\nvalue = [40, 6]'),
#  Text(3993.3061224489797, 2627.4, 'entropy = 0.0\nsamples = 7\nvalue = [7, 0]'),
#  Text(4054.040816326531, 2627.4, 'X[5] <= 12.869\nentropy = 0.619\nsamples = 39\nvalue = [33, 6]'),
#  Text(4023.673469387755, 2446.2, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4084.4081632653065, 2446.2, 'X[2] <= 25.5\nentropy = 0.562\nsamples = 38\nvalue = [33, 5]'),
#  Text(4054.040816326531, 2265.0, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(4114.775510204082, 2265.0, 'X[2] <= 26.5\nentropy = 0.625\nsamples = 32\nvalue = [27, 5]'),
#  Text(4038.857142857143, 2083.8, 'X[5] <= 16.621\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]'),
#  Text(4008.4897959183677, 1902.6, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(4069.2244897959185, 1902.6, 'X[4] <= 1.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(4038.857142857143, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4099.591836734694, 1721.4, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4190.693877551021, 2083.8, 'X[2] <= 28.75\nentropy = 0.516\nsamples = 26\nvalue = [23, 3]'),
#  Text(4160.326530612245, 1902.6, 'entropy = 0.0\nsamples = 10\nvalue = [10, 0]'),
#  Text(4221.061224489797, 1902.6, 'X[5] <= 14.854\nentropy = 0.696\nsamples = 16\nvalue = [13, 3]'),
#  Text(4160.326530612245, 1721.4, 'X[2] <= 29.5\nentropy = 0.971\nsamples = 5\nvalue = [3, 2]'),
#  Text(4129.95918367347, 1540.1999999999998, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4190.693877551021, 1540.1999999999998, 'X[2] <= 30.5\nentropy = 0.811\nsamples = 4\nvalue = [3, 1]'),
#  Text(4160.326530612245, 1359.0, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(4221.061224489797, 1359.0, 'X[2] <= 31.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(4190.693877551021, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4251.428571428572, 1177.7999999999997, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4281.795918367347, 1721.4, 'X[2] <= 31.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(4251.428571428572, 1540.1999999999998, 'entropy = 0.0\nsamples = 8\nvalue = [8, 0]'),
#  Text(4312.163265306122, 1540.1999999999998, 'X[0] <= 2.5\nentropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(4281.795918367347, 1359.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4342.530612244898, 1359.0, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(4114.775510204082, 2989.8, 'X[3] <= 1.0\nentropy = 0.918\nsamples = 3\nvalue = [1, 2]'),
#  Text(4084.4081632653065, 2808.6000000000004, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(4145.142857142858, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4312.163265306122, 3533.4, 'X[5] <= 13.458\nentropy = 0.289\nsamples = 99\nvalue = [94, 5]'),
#  Text(4281.795918367347, 3352.2, 'X[5] <= 13.208\nentropy = 0.4\nsamples = 63\nvalue = [58, 5]'),
#  Text(4251.428571428572, 3171.0, 'X[5] <= 7.91\nentropy = 0.345\nsamples = 62\nvalue = [58, 4]'),
#  Text(4221.061224489797, 2989.8, 'entropy = 0.0\nsamples = 21\nvalue = [21, 0]'),
#  Text(4281.795918367347, 2989.8, 'X[5] <= 7.988\nentropy = 0.461\nsamples = 41\nvalue = [37, 4]'),
#  Text(4251.428571428572, 2808.6000000000004, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4312.163265306122, 2808.6000000000004, 'X[5] <= 10.094\nentropy = 0.384\nsamples = 40\nvalue = [37, 3]'),
#  Text(4281.795918367347, 2627.4, 'entropy = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(4342.530612244898, 2627.4, 'X[2] <= 61.5\nentropy = 0.544\nsamples = 24\nvalue = [21, 3]'),
#  Text(4281.795918367347, 2446.2, 'X[5] <= 12.938\nentropy = 0.439\nsamples = 22\nvalue = [20, 2]'),
#  Text(4251.428571428572, 2265.0, 'entropy = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(4312.163265306122, 2265.0, 'X[2] <= 35.0\nentropy = 0.619\nsamples = 13\nvalue = [11, 2]'),
#  Text(4281.795918367347, 2083.8, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(4342.530612244898, 2083.8, 'X[2] <= 41.5\nentropy = 0.439\nsamples = 11\nvalue = [10, 1]'),
#  Text(4312.163265306122, 1902.6, 'entropy = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(4372.897959183674, 1902.6, 'X[2] <= 46.0\nentropy = 0.722\nsamples = 5\nvalue = [4, 1]'),
#  Text(4342.530612244898, 1721.4, 'entropy = 0.918\nsamples = 3\nvalue = [2, 1]'),
#  Text(4403.265306122449, 1721.4, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(4403.265306122449, 2446.2, 'X[2] <= 64.0\nentropy = 1.0\nsamples = 2\nvalue = [1, 1]'),
#  Text(4372.897959183674, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4433.632653061225, 2265.0, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(4312.163265306122, 3171.0, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(4342.530612244898, 3352.2, 'entropy = 0.0\nsamples = 36\nvalue = [36, 0]')]

# %% [markdown]
# ### Now to get predictions from external data

# %%
test = pd.read_csv("./Test.csv")
test.head()
# Out:
#    pclass                              name     sex   age  sibsp  parch  \
# 0     1.0  Flynn, Mr. John Irwin ("Irving")    male  36.0    0.0    0.0
# 1     3.0      Sage, Miss. Constance Gladys  female   NaN    8.0    2.0
# 2     1.0             Rood, Mr. Hugh Roscoe    male   NaN    0.0    0.0
# 3     2.0      Gillespie, Mr. William Henry    male  34.0    0.0    0.0
# 4     2.0        Collander, Mr. Erik Gustaf    male  28.0    0.0    0.0
#
#      ticket     fare cabin embarked boat  body  \
# 0  PC 17474  26.3875   E25        S    5   NaN
# 1  CA. 2343  69.5500   NaN        S  NaN   NaN
# 2    113767  50.0000   A32        S  NaN   NaN
# 3     12233  13.0000   NaN        S  NaN   NaN
# 4    248740  13.0000   NaN        S  NaN   NaN
#
#                            home.dest
# 0                       Brooklyn, NY
# 1                                NaN
# 2                        Seattle, WA
# 3                      Vancouver, BC
# 4  Helsinki, Finland Ashtabula, Ohio

# %%
# we want only those labels that are in our trainig data set !!!

# %%
labels_needed = np.array(train.columns)
labels_needed
# Out:
# array(['pclass', 'survived', 'sex', 'age', 'sibsp', 'parch', 'fare'],
#       dtype=object)

# %%
test.drop(labels=['name','cabin','boat','body','home.dest','ticket','embarked'], axis=1, inplace= True)

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  300 non-null    float64
#  1   sex     300 non-null    object
#  2   age     234 non-null    float64
#  3   sibsp   300 non-null    float64
#  4   parch   300 non-null    float64
#  5   fare    300 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 14.2+ KB

# %%
## Now to fill NAn
test['age'] = test['age'].fillna(np.mean(test['age']))  # fill age by mean of ages

# %%
# as you see below we have no nan values 
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   pclass  300 non-null    float64
#  1   sex     300 non-null    object
#  2   age     300 non-null    float64
#  3   sibsp   300 non-null    float64
#  4   parch   300 non-null    float64
#  5   fare    300 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 14.2+ KB

# %%
# now to label encode "sex" and "embark"


test['sex'] = le.fit_transform(test['sex'])

# %%
test.head()
# Out:
#    pclass  sex        age  sibsp  parch     fare
# 0     1.0    1  36.000000    0.0    0.0  26.3875
# 1     3.0    0  30.027422    8.0    2.0  69.5500
# 2     1.0    1  30.027422    0.0    0.0  50.0000
# 3     2.0    1  34.000000    0.0    0.0  13.0000
# 4     2.0    1  28.000000    0.0    0.0  13.0000

# %%
X_testing = test.values

# %%
X_testing
# Out:
# array([[ 1.        ,  1.        , 36.        ,  0.        ,  0.        ,
#         26.3875    ],
#        [ 3.        ,  0.        , 30.02742179,  8.        ,  2.        ,
#         69.55      ],
#        [ 1.        ,  1.        , 30.02742179,  0.        ,  0.        ,
#         50.        ],
#        ...,
#        [ 3.        ,  1.        , 13.        ,  4.        ,  2.        ,
#         31.3875    ],
#        [ 3.        ,  1.        , 30.02742179,  2.        ,  0.        ,
#         21.6792    ],
#        [ 3.        ,  0.        , 30.02742179,  0.        ,  0.        ,
#          7.75      ]])

# %%
## now to perform prediction

# %%
survived = dt.predict(X_testing)

# %%
survived = pd.DataFrame({"survived":survived})

# %%
survived
# Out:
#      survived
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 295         0
# 296         1
# 297         0
# 298         0
# 299         0
#
# [300 rows x 1 columns]

# %%
# converting to csv  and save

# %%
#survived.to_csv("./survived.csv")
